# %%
import xlrd

# %% [markdown]
# 获取xls文件

# %%
data = xlrd.open_workbook('/mydata/information.xls')

# %% [markdown]
# 获取到学生信息表

# %%
table = data.sheets()[0]

# %%
for i in range(table.nrows):
    address = table.cell(i,8).value
    if ('北京' in address):
        print ("北京")
    elif ('天津' in address):
        print ("天津")
    elif ('上海' in address):
        print ("上海")
    elif ('重庆' in address):
        print ("重庆")
    elif ('青海' in address):
        print ("西宁")
    elif ('湖南' in address):
        print ("长沙")
    elif ('湖北' in address):
        print ("武汉")
    elif ('西藏' in address):
        print ("拉萨")
    elif ('新疆' in address):
        print ("乌鲁木齐")
    elif ('福建' in address):
        print ("福州")
    elif ('广东' in address):
        print ("广州")
    elif ('云南' in address):
        print ("昆明")
    elif ('陕西' in address):
        print ("西安")
    elif ('山东' in address):
        print ("济南")
    elif ('甘肃' in address):
        print ("兰州")
    elif ('山西' in address):
        print ("太原")
    elif ('吉林' in address):
        print ("长春")
    elif ('贵州' in address):
        print ("贵阳")
    elif ('海南' in address):
        print ("海口")
    elif ('四川' in address):
        print ("成都")
    elif ('江西' in address):
        print ("南昌")
    elif ('内蒙' in address):
        print ("呼和浩特")
    elif ('宁夏' in address):
        print ("银川")
    elif ('江西' in address):
        print ("南昌")
    elif ('浙江' in address):
        print ("杭州")
    elif ('江苏' in address):
        print ("南京")
    elif ('广西' in address):
        print ("南宁")
    elif ('河南' in address):
        print ("郑州")
    elif ('安徽' in address):
        print ("合肥")
    elif ('黑龙江' in address):
        print ("哈尔滨")
    elif ('辽宁' in address):
        print ("沈阳")
    elif ('河北' in address):
        print ("石家庄")
        
    
    else:
        print (address + "[+]未成功匹配")
# Out:
# 实际所在地[+]未成功匹配
# 广州
# 广州
# 长沙
# 长沙
# [+]未成功匹配
# 上海
# 武汉
# 武汉
# 北京
# 郑州
# 广州
# 广州
# 广州
# 济南
# [+]未成功匹配
# 广州
# 广州
# 广州
# 广州
# 广州
# 广州
# 广州
# 天津
# 天津
# 郑州
# 北京
# 广州
# 长沙
# [+]未成功匹配
# 天津
# 天津
# 武汉
# [+]未成功匹配
# 长沙
# 广州
# 西安
# 广州
# 广州
# 广州
# 长沙
# 广州
# 广州
# [+]未成功匹配
# 广州
# 长沙
# 天津
# [+]未成功匹配
# 长沙
# 长沙
# 成都
# 长沙
# 长沙
# 广州
# 长沙
# 武汉
# 杭州
# 长沙
# 郑州
# 广州
# 长沙
# [+]未成功匹配
# 长沙
# 武汉
# 西安
# 昆明
# 济南
# 长沙
# 长沙
# 广州
# 武汉
# 北京
# 石家庄
# 长沙
# 天津
# 广州
# 杭州
# 石家庄
# 长沙
# 长沙
# 成都
# 上海
# 南京
# 广州
# 广州
# 南京
# 长沙
# 长沙
# 南京
# 成都
# 杭州
# 广州
# 北京
# 太原
# 长沙
# 长沙
# 成都
# 杭州
# 成都
# 济南
# 西宁
# 长沙
# [+]未成功匹配
# 西安
# 西宁
# 济南
# 长沙
# 福州
# 长沙
# 兰州
# 广州
# 广州
# [+]未成功匹配
# 西安
# 昆明
# [+]未成功匹配
# 哈尔滨
# 武汉
# 广州
# 广州
# 广州
# 武汉
# [+]未成功匹配
# 长沙
# 西安
# 乌鲁木齐
# 广州
# 西安
# 长沙
# 广州
# 南宁
# 上海
# 济南
# [+]未成功匹配
# 重庆
# 广州
# 天津
# 福州
# 南京
# 郑州
# 成都
# [+]未成功匹配
# 北京
# 武汉
# 成都
# [+]未成功匹配
# [+]未成功匹配
# 福州
# 广州
# 长沙
# 天津
# 长沙
# 天津
# [+]未成功匹配
# 武汉
# 长沙
# 长沙
# 重庆
# 重庆
# 郑州
# 重庆
# 长沙
# [+]未成功匹配
# 武汉
# [+]未成功匹配
# 福州
# 广州
# 广州
# 广州
# 哈尔滨
# 贵阳
# 长沙
# 福州
# 武汉
# 兰州
# ...

# %%
ctype = 1
value = 'lalala'
xf = 0 
table.put_cell(0, 9, 1, value, 0)
table.cell(0,9).value
# Out:
# 'lalala'

# %%
for i in range(table.nrows):
    address = table.cell(i,8).value
    if ('北京' in address):
        print ("北京")
        table.put_cell(i, 9, 1, "北京", 0)
    elif ('天津' in address):
        print ("天津")
        table.put_cell(i, 9, 1, "天津", 0)
    elif ('上海' in address):
        print ("上海")
        table.put_cell(i, 9, 1, "上海", 0)
    elif ('重庆' in address):
        print ("重庆")
        table.put_cell(i, 9, 1, "重庆", 0)
    elif ('青海' in address):
        print ("西宁")
        table.put_cell(i, 9, 1, "西宁", 0)
    elif ('湖南' in address):
        print ("长沙")
        table.put_cell(i, 9, 1, "长沙", 0)
    elif ('湖北' in address):
        print ("武汉")
        table.put_cell(i, 9, 1, "武汉", 0)
    elif ('西藏' in address):
        print ("拉萨")
        table.put_cell(i, 9, 1, "拉萨", 0)
    elif ('新疆' in address):
        print ("乌鲁木齐")
        table.put_cell(i, 9, 1, "乌鲁木齐", 0)
    elif ('福建' in address):
        print ("福州")
        table.put_cell(i, 9, 1, "福州", 0)
    elif ('广东' in address):
        print ("广州")
        table.put_cell(i, 9, 1, "广州", 0)
    elif ('云南' in address):
        print ("昆明")
        table.put_cell(i, 9, 1, "昆明", 0)
    elif ('陕西' in address):
        print ("西安")
        table.put_cell(i, 9, 1, "西安", 0)
    elif ('山东' in address):
        print ("济南")
        table.put_cell(i, 9, 1, "济南", 0)
    elif ('甘肃' in address):
        print ("兰州")
        table.put_cell(i, 9, 1, "兰州", 0)
    elif ('山西' in address):
        print ("太原")
        table.put_cell(i, 9, 1, "太原", 0)
    elif ('吉林' in address):
        print ("长春")
        table.put_cell(i, 9, 1, "长春", 0)
    elif ('贵州' in address):
        print ("贵阳")
        table.put_cell(i, 9, 1, "贵阳", 0)
    elif ('海南' in address):
        print ("海口")
        table.put_cell(i, 9, 1, "海口", 0)
    elif ('四川' in address):
        print ("成都")
        table.put_cell(i, 9, 1, "成都", 0)
    elif ('内蒙' in address):
        print ("呼和浩特")
        table.put_cell(i, 9, 1, "呼和浩特", 0)
    elif ('宁夏' in address):
        print ("银川")
        table.put_cell(i, 9, 1, "银川", 0)
    elif ('江西' in address):
        print ("南昌")
        table.put_cell(i, 9, 1, "南昌", 0)
    elif ('浙江' in address):
        print ("杭州")
        table.put_cell(i, 9, 1, "杭州", 0)
    elif ('江苏' in address):
        print ("南京")
        table.put_cell(i, 9, 1, "南京", 0)
    elif ('广西' in address):
        print ("南宁")
        table.put_cell(i, 9, 1, "南宁", 0)
    elif ('河南' in address):
        print ("郑州")
        table.put_cell(i, 9, 1, "郑州", 0)
    elif ('安徽' in address):
        print ("合肥")
        table.put_cell(i, 9, 1, "合肥", 0)
    elif ('黑龙江' in address):
        print ("哈尔滨")
        table.put_cell(i, 9, 1, "哈尔滨", 0)
    elif ('辽宁' in address):
        print ("沈阳")
        table.put_cell(i, 9, 1, "沈阳", 0)
    elif ('河北' in address):
        print ("石家庄")
        table.put_cell(i, 9, 1, "石家庄", 0)
        
    else:
        print (address + "[+]未成功匹配")
# Out:
# 实际所在地[+]未成功匹配
# 广州
# 广州
# 长沙
# 长沙
# [+]未成功匹配
# 上海
# 武汉
# 武汉
# 北京
# 郑州
# 广州
# 广州
# 广州
# 济南
# [+]未成功匹配
# 广州
# 广州
# 广州
# 广州
# 广州
# 广州
# 广州
# 天津
# 天津
# 郑州
# 北京
# 广州
# 长沙
# [+]未成功匹配
# 天津
# 天津
# 武汉
# [+]未成功匹配
# 长沙
# 广州
# 西安
# 广州
# 广州
# 广州
# 长沙
# 广州
# 广州
# [+]未成功匹配
# 广州
# 长沙
# 天津
# [+]未成功匹配
# 长沙
# 长沙
# 成都
# 长沙
# 长沙
# 广州
# 长沙
# 武汉
# 杭州
# 长沙
# 郑州
# 广州
# 长沙
# [+]未成功匹配
# 长沙
# 武汉
# 西安
# 昆明
# 济南
# 长沙
# 长沙
# 广州
# 武汉
# 北京
# 石家庄
# 长沙
# 天津
# 广州
# 杭州
# 石家庄
# 长沙
# 长沙
# 成都
# 上海
# 南京
# 广州
# 广州
# 南京
# 长沙
# 长沙
# 南京
# 成都
# 杭州
# 广州
# 北京
# 太原
# 长沙
# 长沙
# 成都
# 杭州
# 成都
# 济南
# 西宁
# 长沙
# [+]未成功匹配
# 西安
# 西宁
# 济南
# 长沙
# 福州
# 长沙
# 兰州
# 广州
# 广州
# [+]未成功匹配
# 西安
# 昆明
# [+]未成功匹配
# 哈尔滨
# 武汉
# 广州
# 广州
# 广州
# 武汉
# [+]未成功匹配
# 长沙
# 西安
# 乌鲁木齐
# 广州
# 西安
# 长沙
# 广州
# 南宁
# 上海
# 济南
# [+]未成功匹配
# 重庆
# 广州
# 天津
# 福州
# 南京
# 郑州
# 成都
# [+]未成功匹配
# 北京
# 武汉
# 成都
# [+]未成功匹配
# [+]未成功匹配
# 福州
# 广州
# 长沙
# 天津
# 长沙
# 天津
# [+]未成功匹配
# 武汉
# 长沙
# 长沙
# 重庆
# 重庆
# 郑州
# 重庆
# 长沙
# [+]未成功匹配
# 武汉
# [+]未成功匹配
# 福州
# 广州
# 广州
# 广州
# 哈尔滨
# 贵阳
# 长沙
# 福州
# 武汉
# 兰州
# ...

# %%
dict_address = { '北京': 0,'拉萨': 0,'上海': 0,'广州': 0,'武汉': 0,'长沙': 0,'济南': 0,'天津': 0,'石家庄': 0,'西安': 0,'天津': 0,'重庆': 0,'西宁': 0,'昆明': 0,'沈阳': 0,'哈尔滨': 0,'合肥': 0,'郑州': 0,'南宁': 0,'南京': 0,'杭州': 0,'南昌': 0,'银川': 0,'呼和浩特': 0,'海口': 0,'贵阳': 0,'长春': 0,'太原': 0,'兰州': 0,'福州': 0,'乌鲁木齐': 0,'成都': 0};

# %%
print (dict_address)
# Out:
# {'济南': 0, '南京': 0, '合肥': 0, '兰州': 0, '昆明': 0, '北京': 0, '武汉': 0, '郑州': 0, '拉萨': 0, '海口': 0, '上海': 0, '广州': 0, '成都': 0, '呼和浩特': 0, '南昌': 0, '西宁': 0, '太原': 0, '石家庄': 0, '贵阳': 0, '重庆': 0, '哈尔滨': 0, '长沙': 0, '西安': 0, '沈阳': 0, '杭州': 0, '长春': 0, '天津': 0, '南宁': 0, '福州': 0, '乌鲁木齐': 0, '银川': 0}

# %%
for i in range(table.nrows):
    address = table.cell(i,8).value
    if ('北京' in address):
        print ("北京")
        table.put_cell(i, 9, 1, "北京", 0)
        dict_address["北京"] += 1
    elif ('天津' in address):
        print ("天津")
        table.put_cell(i, 9, 1, "天津", 0)
        dict_address["天津"] += 1
    elif ('上海' in address):
        print ("上海")
        table.put_cell(i, 9, 1, "上海", 0)
        dict_address["上海"] += 1
    elif ('重庆' in address):
        print ("重庆")
        table.put_cell(i, 9, 1, "重庆", 0)
        dict_address["重庆"] += 1
    elif ('青海' in address):
        print ("西宁")
        table.put_cell(i, 9, 1, "西宁", 0)
        dict_address["西宁"] += 1
    elif ('湖南' in address):
        print ("长沙")
        table.put_cell(i, 9, 1, "长沙", 0)
        dict_address["长沙"] += 1
    elif ('湖北' in address):
        print ("武汉")
        table.put_cell(i, 9, 1, "武汉", 0)
        dict_address["武汉"] += 1
    elif ('西藏' in address):
        print ("拉萨")
        table.put_cell(i, 9, 1, "拉萨", 0)
        dict_address["拉萨"] += 1
    elif ('新疆' in address):
        print ("乌鲁木齐")
        table.put_cell(i, 9, 1, "乌鲁木齐", 0)
        dict_address["乌鲁木齐"] += 1
    elif ('福建' in address):
        print ("福州")
        table.put_cell(i, 9, 1, "福州", 0)
        dict_address["福州"] += 1
    elif ('广东' in address):
        print ("广州")
        table.put_cell(i, 9, 1, "广州", 0)
        dict_address["广州"] += 1
    elif ('云南' in address):
        print ("昆明")
        table.put_cell(i, 9, 1, "昆明", 0)
        dict_address["昆明"] += 1
    elif ('陕西' in address):
        print ("西安")
        table.put_cell(i, 9, 1, "西安", 0)
        dict_address["西安"] += 1
    elif ('山东' in address):
        print ("济南")
        table.put_cell(i, 9, 1, "济南", 0)
        dict_address["济南"] += 1
    elif ('甘肃' in address):
        print ("兰州")
        table.put_cell(i, 9, 1, "兰州", 0)
        dict_address["兰州"] += 1
    elif ('山西' in address):
        print ("太原")
        table.put_cell(i, 9, 1, "太原", 0)
        dict_address["太原"] += 1
    elif ('吉林' in address):
        print ("长春")
        table.put_cell(i, 9, 1, "长春", 0)
        dict_address["长春"] += 1
    elif ('贵州' in address):
        print ("贵阳")
        table.put_cell(i, 9, 1, "贵阳", 0)
        dict_address["贵阳"] += 1
    elif ('海南' in address):
        print ("海口")
        table.put_cell(i, 9, 1, "海口", 0)
        dict_address["海口"] += 1
    elif ('四川' in address):
        print ("成都")
        table.put_cell(i, 9, 1, "成都", 0)
        dict_address["成都"] += 1
    elif ('内蒙' in address):
        print ("呼和浩特")
        table.put_cell(i, 9, 1, "呼和浩特", 0)
        dict_address["呼和浩特"] += 1
    elif ('宁夏' in address):
        print ("银川")
        table.put_cell(i, 9, 1, "银川", 0)
        dict_address["银川"] += 1
    elif ('江西' in address):
        print ("南昌")
        table.put_cell(i, 9, 1, "南昌", 0)
        dict_address["南昌"] += 1
    elif ('浙江' in address):
        print ("杭州")
        table.put_cell(i, 9, 1, "杭州", 0)
        dict_address["杭州"] += 1
    elif ('江苏' in address):
        print ("南京")
        table.put_cell(i, 9, 1, "南京", 0)
        dict_address["南京"] += 1
    elif ('广西' in address):
        print ("南宁")
        table.put_cell(i, 9, 1, "南宁", 0)
        dict_address["南宁"] += 1
    elif ('河南' in address):
        print ("郑州")
        table.put_cell(i, 9, 1, "郑州", 0)
        dict_address["郑州"] += 1
    elif ('安徽' in address):
        print ("合肥")
        table.put_cell(i, 9, 1, "合肥", 0)
        dict_address["合肥"] += 1
    elif ('黑龙江' in address):
        print ("哈尔滨")
        table.put_cell(i, 9, 1, "哈尔滨", 0)
        dict_address["哈尔滨"] += 1
    elif ('辽宁' in address):
        print ("沈阳")
        table.put_cell(i, 9, 1, "沈阳", 0)
        dict_address["沈阳"] += 1
    elif ('河北' in address):
        print ("石家庄")
        table.put_cell(i, 9, 1, "石家庄", 0)
        dict_address["石家庄"] += 1
    elif ('西藏' in address):
        print ("拉萨")
        table.put_cell(i, 9, 1, "拉萨", 0)
        dict_address["拉萨"] += 1
        
    else:
        print (address + "[+]未成功匹配")
# Out:
# 实际所在地[+]未成功匹配
# 广州
# 广州
# 长沙
# 长沙
# [+]未成功匹配
# 上海
# 武汉
# 武汉
# 北京
# 郑州
# 广州
# 广州
# 广州
# 济南
# [+]未成功匹配
# 广州
# 广州
# 广州
# 广州
# 广州
# 广州
# 广州
# 天津
# 天津
# 郑州
# 北京
# 广州
# 长沙
# [+]未成功匹配
# 天津
# 天津
# 武汉
# [+]未成功匹配
# 长沙
# 广州
# 西安
# 广州
# 广州
# 广州
# 长沙
# 广州
# 广州
# [+]未成功匹配
# 广州
# 长沙
# 天津
# [+]未成功匹配
# 长沙
# 长沙
# 成都
# 长沙
# 长沙
# 广州
# 长沙
# 武汉
# 杭州
# 长沙
# 郑州
# 广州
# 长沙
# [+]未成功匹配
# 长沙
# 武汉
# 西安
# 昆明
# 济南
# 长沙
# 长沙
# 广州
# 武汉
# 北京
# 石家庄
# 长沙
# 天津
# 广州
# 杭州
# 石家庄
# 长沙
# 长沙
# 成都
# 上海
# 南京
# 广州
# 广州
# 南京
# 长沙
# 长沙
# 南京
# 成都
# 杭州
# 广州
# 北京
# 太原
# 长沙
# 长沙
# 成都
# 杭州
# 成都
# 济南
# 西宁
# 长沙
# [+]未成功匹配
# 西安
# 西宁
# 济南
# 长沙
# 福州
# 长沙
# 兰州
# 广州
# 广州
# [+]未成功匹配
# 西安
# 昆明
# [+]未成功匹配
# 哈尔滨
# 武汉
# 广州
# 广州
# 广州
# 武汉
# [+]未成功匹配
# 长沙
# 西安
# 乌鲁木齐
# 广州
# 西安
# 长沙
# 广州
# 南宁
# 上海
# 济南
# [+]未成功匹配
# 重庆
# 广州
# 天津
# 福州
# 南京
# 郑州
# 成都
# [+]未成功匹配
# 北京
# 武汉
# 成都
# [+]未成功匹配
# [+]未成功匹配
# 福州
# 广州
# 长沙
# 天津
# 长沙
# 天津
# [+]未成功匹配
# 武汉
# 长沙
# 长沙
# 重庆
# 重庆
# 郑州
# 重庆
# 长沙
# [+]未成功匹配
# 武汉
# [+]未成功匹配
# 福州
# 广州
# 广州
# 广州
# 哈尔滨
# 贵阳
# 长沙
# 福州
# 武汉
# 兰州
# ...

# %%
print (dict_address)
# Out:
# {'济南': 23, '南京': 21, '合肥': 4, '兰州': 4, '昆明': 11, '北京': 32, '武汉': 47, '郑州': 15, '拉萨': 0, '海口': 4, '上海': 16, '广州': 192, '成都': 22, '呼和浩特': 3, '南昌': 2, '西宁': 5, '太原': 5, '石家庄': 7, '贵阳': 5, '重庆': 4, '哈尔滨': 4, '长沙': 164, '西安': 12, '沈阳': 6, '杭州': 39, '长春': 0, '天津': 15, '南宁': 7, '福州': 11, '乌鲁木齐': 9, '银川': 2}
